# %%
#Import library
import pandas as pd
import numpy as np

#Membuat Series

nilai = pd.Series([90,85,75,100])
print(nilai)

nilai = pd.Series(['Ana','Kiko','Ryan','Ben'])
print(nilai)
# Out:
# 0     90
# 1     85
# 2     75
# 3    100
# dtype: int64
# 0     Ana
# 1    Kiko
# 2    Ryan
# 3     Ben
# dtype: object

# %%
#Membuat DataFrame
data = {'Nama':['Andi','Budi','Citra'],'Umur':[20,21,22],'Kota':['Medan','Jakarta','Bandung']}
df = pd.DataFrame(data)
print(df)
# Out:
#     Nama  Umur     Kota
# 0   Andi    20    Medan
# 1   Budi    21  Jakarta
# 2  Citra    22  Bandung

# %%
#Membaca Dataset
df = pd.read_csv('Data Penjualan Toko Buku.csv')
print(df)
df.head()
df.tail()
df.info()
df.describe()

df['jenis_item']
df[['jenis_item','jumlah']]
df.iloc[0]
df.iloc[0:7]
df.loc[0]

df.drop('jenis_item',axis=1)
df.rename(columns={'jumlah':'quantity'})
# Out:
#       id_transaksi       jenis_item  jumlah tanggal pembelian nama_customer  \
# 0         133889.0       Alat Tulis       1          1/1/2010  Stacy Campos
# 1         133889.0     Buku Sejarah       1          1/1/2010  Stacy Campos
# 2         133889.0   Buku Anak-Anak       2          1/1/2010  Stacy Campos
# 3         133889.0  Majalah Fashion       1          1/1/2010  Stacy Campos
# 4         133889.0   Majalah Berita       2          1/1/2010  Stacy Campos
# ...            ...              ...     ...               ...           ...
# 3235           NaN              NaN       2         4/30/2024           NaN
# 3236           NaN              NaN       6         4/30/2024           NaN
# 3237           NaN              NaN       1         4/30/2024           NaN
# 3238           NaN              NaN       9         4/30/2024           NaN
# 3239           NaN              NaN       1         4/30/2024           NaN
#
#           total
# 0      120000.0
# 1      150000.0
# ...

# %%
df.duplicated()
df.drop_duplicates()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3235     True
# 3236     True
# 3237     True
# 3238     True
# 3239     True
# Length: 3240, dtype: bool

# %%
df.isnull()
df.isnull().sum()
# Out:
# id_transaksi         771
# jenis_item           771
# jumlah                 0
# tanggal pembelian      3
# nama_customer        771
# total                  2
# dtype: int64

# %%
df['id_transaksi']=df['id_transaksi']
df.dropna()
# Out:
#       id_transaksi       jenis_item  jumlah tanggal pembelian  nama_customer  \
# 0         133889.0       Alat Tulis       1          1/1/2010   Stacy Campos
# 1         133889.0     Buku Sejarah       1          1/1/2010   Stacy Campos
# 2         133889.0   Buku Anak-Anak       2          1/1/2010   Stacy Campos
# 3         133889.0  Majalah Fashion       1          1/1/2010   Stacy Campos
# 4         133889.0   Majalah Berita       2          1/1/2010   Stacy Campos
# ...            ...              ...     ...               ...            ...
# 2464      134294.0       Alat Tulis       3         4/30/2024  Richard Jones
# 2465      134294.0     Buku Sejarah       4         4/30/2024  Richard Jones
# 2466      134294.0   Buku Anak-Anak       2         4/30/2024  Richard Jones
# 2467      134294.0  Majalah Fashion       9         4/30/2024  Richard Jones
# 2468      134294.0   Majalah Berita       4         4/30/2024  Richard Jones
#
#           total
# 0      120000.0
# ...
